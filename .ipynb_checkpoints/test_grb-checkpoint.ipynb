# %% [markdown]
# 🌿Preprocessing

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import pickle

# load test data
mnist_path = "/home/ajay2425/rclass/mnist_dataset/mnist.npz" #main
with np.load(mnist_path) as data:
    x_test = data["x_test"]
    y_test = data["y_test"]
print(f"x_test shape: {x_test.shape}, y_test shape: {y_test.shape}")

# 1. Flatten
x_test_flat = x_test.reshape(x_test.shape[0], -1)
print(f"1. x_test_flat shape: {x_test_flat.shape}, y_test shape: {y_test.shape}")

# 2. Subsets
subset_size = 1000
x_test_subset = x_test_flat[:subset_size]
y_test_subset = y_test[:subset_size]
print(f"2. x_test_subset shape: {x_test_subset.shape}")

# 3. PCA
pca_model_path = "/home/ajay2425/rclass/models/models_grb/trained_pca.pkl" #main
# pca_model_path = "/home/ajay2425/rclass/models/add/trained_pca.pkl" # temp.
with open(pca_model_path, "rb") as file:
    pca = pickle.load(file)
print("(trained pca model loaded)")
# apply pca to the test data
x_test_pca = pca.transform(x_test_subset)  # Use the same pca model from training
print(f"3. x_test_pca shape: {x_test_pca.shape}")
variance = np.sum(pca.explained_variance_ratio_)
print(f"variance = {variance}")

# # 3. PCA
# n_components = 30
# d = 2 # degree
# pca = PCA(n_components=n_components)
# x_test_pca = pca.fit_transform(x_test_subset)
# print(f"3. x_test_pca shape: {x_test_pca.shape}")
# variance = np.sum(pca.explained_variance_ratio_)
# print(f"variance = {variance}")

# # 4. Binarize
# threshold_value = 0
# x_test_norm = (x_test_pca > threshold_value).astype(int)
# print(f"4. x_test_norm shape: {x_test_norm.shape}")

# 4. Normalize
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))
x_test_norm = scaler.fit_transform(x_test_pca)
print(f"4. x_test_norm shape: {x_test_norm.shape}")
# Out:
# x_test shape: (10000, 28, 28), y_test shape: (10000,)
# 1. x_test_flat shape: (10000, 784), y_test shape: (10000,)
# 2. x_test_subset shape: (1000, 784)
# (trained pca model loaded)
# 3. x_test_pca shape: (1000, 15)
# variance = 0.5934609622982091
# 4. x_test_norm shape: (1000, 15)

# %% [markdown]
# 🌿Generate multi-indices

# %%
import time
# Start timer
start_time = time.time()

def r_multi_indices(n, d):
    if n == 1:
        yield (d,)
    else:
        for k in range(d + 1):
            for c in r_multi_indices(n - 1, k):
                yield (d - k, *c)

def generate_multi_indices(n, d):
    from itertools import chain
    return list(chain(*[list(r_multi_indices(n, _)) for _ in range(d + 1)]))

import pickle
import os
models_dir = "/home/ajay2425/rclass/models/models_grb/"
# models_dir = "/home/ajay2425/rclass/models/add/" #temp.
# Load the model for the current digit
model_path = f"{models_dir}/classifier_0.pkl"
with open(model_path, "rb") as file:
    model = pickle.load(file)
# Extract model parameters
n_components = model["n_components"]
d = model["degree"]
c = generate_multi_indices(n_components, d)
print(f"no_of_coeff =", len(c))
# Out:
# no_of_coeff = 136

# %% [markdown]
# 🌿Generate polynomials

# %%
import numpy as np
def construct_G_H_matrices(x_test_norm, n, d):
    num_data_points = x_test_norm.shape[0]
    multi_indices = generate_multi_indices(n, d)
    num_coefficients = len(multi_indices)

    # Initialize G and H matrices
    G = []
    H = []

    # Construct G and H using multi-indices
    for i in range(num_data_points):
        G_row = []
        H_row = []
        for idx in multi_indices:
            term = np.prod([x_test_norm[i, k] ** idx[k] for k in range(n)])
            G_row.append(term)
            H_row.append(term)
        G.append(G_row)
        H.append(H_row)

    # Convert G and H to NumPy arrays
    G = np.array(G)
    H = np.array(H)

    # # Normalize G and H row-wise for numerical stability
    # G = G / np.linalg.norm(G, axis=1, keepdims=True)
    # H = H / np.linalg.norm(H, axis=1, keepdims=True)

    return G, H, multi_indices

# %% [markdown]
# 🌿Load saved models

# %%
import pickle
import os

models_dir = "/home/ajay2425/rclass/models/models_grb/"
# models_dir = "/home/ajay2425/rclass/models/add/" #temp.

# Load all classifiers into memory
classifiers = {}
for digit in range(10):
    model_path = f"{models_dir}/classifier_{digit}.pkl"
    if os.path.exists(model_path):
        with open(model_path, "rb") as file:
            classifiers[digit] = pickle.load(file)
    else:
        print(f"Model for digit {digit} not found!")

# print(f"Loaded classifiers for digits: {list(classifiers.keys())}")

# %% [markdown]
# 🌿Test

# %%
from sklearn.metrics import accuracy_score

# Initialize an array to store predictions
predictions = []

# Loop through each test sample
for i, test_samples in enumerate(x_test_norm):
    confidence_scores = []

    # Pass the test sample through each classifier
    for digit in range(10):

        # Load the model for the current digit
        model_path = f"{models_dir}/classifier_{digit}.pkl"
        with open(model_path, "rb") as file:
            model = pickle.load(file)
        # Extract model parameters
        alpha = model["alpha"]
        beta = model["beta"]
        theta = model["theta"]
        multi_indices = model["multi_indices"]

        test_sample_array = np.array([test_samples])

        # Compute the rational function value for the current classifier
        G, H, _ = construct_G_H_matrices(test_sample_array, model["n_components"],  model["degree"])
        numerator = np.dot(G[0], alpha)
        denominator = np.dot(H[0], beta)
        # if np.abs(denominator) < 1e-8:
        if np.abs(denominator) == 0:
            denominator = 1e-8  # to prevent division by zero
        rational_values = numerator / denominator

        # Append the confidence score for this classifier
        confidence_scores.append(rational_values)

    # Determine the predicted digit (index of the highest confidence score)
    predicted_digit = np.argmax(confidence_scores)
    predictions.append(predicted_digit)

    # Debugging (optional): Print the confidence scores
    True_digit = y_test[i]
    print(f"Test Sample {i}: Confidence Scores = {confidence_scores}, Predicted Digit = {predicted_digit}, True Digit = {True_digit}")

#-----------------------------------------
# Evaluate accuracy
accuracy = accuracy_score(y_test_subset, predictions)
print(f"Overall Testing Accuracy: {accuracy * 100:.2f}%")

# # Optional: Save predictions and confidence scores for further analysis
# results = {"predictions": predictions, "confidence_scores": confidence_scores}
# with open("testing_results.pkl", "wb") as file:
#     pickle.dump(results, file)
    

# Stop timer
testing_time = time.time() - start_time
print(f"Total Testing Time: {testing_time:.2f} seconds")
# Out:
# Test Sample 0: Confidence Scores = [-0.6396235906705191, -0.6102951624768684, -0.7856447010582153, -0.8253719336468477, -1.2309315772196343, -1.3221685049700742, -0.5335596163570343, 0.4569781739830353, -0.5969199920007835, -0.04990403503568373], Predicted Digit = 7, True Digit = 7
# Test Sample 1: Confidence Scores = [-1.4957312351977694, -0.7293618456476463, -0.16442137139750718, -0.44302165948632216, -1.7938571108673655, -2.138998922155202, -0.05787245500685994, -1.0303110035941967, -0.7818201168858392, -1.043350355142206], Predicted Digit = 6, True Digit = 2
# Test Sample 2: Confidence Scores = [-1.1751971243492596, 0.3577541693061491, -0.8551812021363849, -1.0075511427388923, -0.5179962559348851, -0.645631689046428, -0.3864242190679679, -0.5426211930946446, -0.9631922128343167, -0.5491605219952258], Predicted Digit = 1, True Digit = 1
# Test Sample 3: Confidence Scores = [0.7933679481305004, -0.9207659839655915, -0.8657018271930326, -0.20049630700473792, -1.3629593252540786, -0.8882961898286479, -1.1431499981616744, -0.45532385148949417, -0.947158047639068, -0.5798766053288615], Predicted Digit = 0, True Digit = 0
# Test Sample 4: Confidence Scores = [-1.2389673291635321, -0.9778949053746534, -0.9926082981691056, -1.117448277333036, 0.2250800499239392, -1.5311998759032996, -0.9260507415241883, -0.8178278862995617, -0.8202767786064117, -0.09044187381862259], Predicted Digit = 4, True Digit = 4
# Test Sample 5: Confidence Scores = [-1.2240236730614327, 0.6064126545347185, -0.9429177081704273, -1.070442435714764, -0.24212297037312874, -1.1153836125395178, -0.6746460476643721, -0.509404534215571, -1.3552526937446319, -0.7418425385255173], Predicted Digit = 1, True Digit = 1
# Test Sample 6: Confidence Scores = [-1.0408290359464212, -1.3719995284918092, -0.423456583220944, -1.2043959427987203, 0.4571995994851423, -0.062138670801947536, -0.8142771157351314, -0.9325797782333999, -0.6049765626863736, -1.1291245329994517], Predicted Digit = 4, True Digit = 4
# Test Sample 7: Confidence Scores = [-1.0724124420471963, -1.039317013922428, -0.3982769784401437, -0.5173042038229586, 0.045879310461176395, -0.8534451169342206, -0.7084712314516243, -0.8975461141952746, -0.14203454351455175, -0.03415764485097658], Predicted Digit = 4, True Digit = 9
# Test Sample 8: Confidence Scores = [-1.2074311455742919, -1.3079939848645217, -0.023715343827416795, -1.5075005156602685, -0.7682586802684451, -0.1257587910290757, -1.3257678660864571, -0.7949212364480053, -0.9457566562242283, -0.5403301555809106], Predicted Digit = 2, True Digit = 5
# Test Sample 9: Confidence Scores = [-0.8973239409622866, -1.584595047776566, -1.8028605403840552, -1.5928968701248105, -0.36791562911961356, -0.9493867524057092, -1.6646936992043073, -0.4033739153146888, -1.751440029686962, -0.13027305731440403], Predicted Digit = 9, True Digit = 9
# Test Sample 10: Confidence Scores = [0.2844140188397963, -0.7230828662453324, -1.1392042112503875, -0.3864700543390803, -0.9667419645393855, -0.8005795420386774, -1.4306911375302005, -1.0912819906307265, -1.0839728693713524, -0.5565718246929797], Predicted Digit = 0, True Digit = 0
# Test Sample 11: Confidence Scores = [-1.1096504601336363, -1.1635464234500756, -1.0775514273110958, -1.235717904856134, 0.052561930004920765, -0.2508654102891135, 0.6551494579506675, -1.0875295793487934, -0.6580513418413176, -1.1771981008760701], Predicted Digit = 6, True Digit = 6
# Test Sample 12: Confidence Scores = [-0.959985533277952, -1.0354727527455796, -1.2617395837220735, -1.5707630843951543, -0.06350763155056718, -0.7545029332400773, -1.478217042280946, -0.9840269141298948, -1.1403587060337124, 0.3503287491208993], Predicted Digit = 9, True Digit = 9
# Test Sample 13: Confidence Scores = [1.568957967282935, -0.8829649621216243, -0.6732764878794739, -1.047649364163962, -0.3430565209647899, -1.038354434648825, -0.04506696930002854, -1.0886488103874417, -0.8422707530395268, -0.6255911225226479], Predicted Digit = 0, True Digit = 0
# Test Sample 14: Confidence Scores = [-0.9623991554737167, 0.6228510092197055, -0.9816878200639221, -1.918801001880434, -0.46100188311434687, -0.7580914093637117, -1.0975313949422962, -0.8449274418318778, -1.2835012232850798, -0.7910882177460267], Predicted Digit = 1, True Digit = 1
# Test Sample 15: Confidence Scores = [-1.1266752599556606, -1.2214000724707879, -0.45467102656980757, -0.26493635544782995, -0.8063190480933077, 0.2059333852478489, -0.6670980597944047, -0.6922463730574823, -0.44765016452031725, -0.36878113810471164], Predicted Digit = 5, True Digit = 5
# Test Sample 16: Confidence Scores = [-1.082284224249144, -1.0188433635066105, -1.3348520299290267, -1.0264016563069158, -0.3767369618439129, -1.1649235193980503, -1.3015689647214261, -0.6586130695800505, -0.8753974623619244, 0.3053228711177679], Predicted Digit = 9, True Digit = 9
# Test Sample 17: Confidence Scores = [-0.5733081759598717, -0.9115405604020783, -0.7791666397742681, -0.4489258463395453, -1.291257907662111, -1.5199565781751077, -1.383692540690578, 0.9912291803335627, -1.0436406820653559, -0.42279309647431434], Predicted Digit = 7, True Digit = 7
# Test Sample 18: Confidence Scores = [-1.2767448681147007, -1.0907266213608504, -0.3667851866632476, -0.17428583201783415, -1.3347835093458071, -0.8043927719662922, -0.3350807621508517, -0.6788271798301666, -0.18634326639016083, -0.30131798933760884], Predicted Digit = 3, True Digit = 3
# Test Sample 19: Confidence Scores = [-0.9767075061346457, -1.0779855966351009, -0.67009368950696, -1.147744181460871, 0.7936738761498766, -0.9752363517099706, -1.5194883963420276, -0.5914230871781239, -0.9306368582004803, -0.3685480260940098], Predicted Digit = 4, True Digit = 4
# Test Sample 20: Confidence Scores = [-0.41907951286939515, -0.9828980563323385, -1.4536914829095378, -1.733659877723567, -0.8071076837733216, -0.6680167464392891, -1.4600148632485759, -1.3639286367517678, -2.326229644659951, 0.2036486077632918], Predicted Digit = 9, True Digit = 9
# Test Sample 21: Confidence Scores = [-0.903653028133872, -1.2835982501090226, -1.1975396798235982, -0.814448025750913, -0.2623518686120414, -0.4728716360381643, 0.5309355452188855, -0.7138102667608706, -0.5650278509284917, -1.0825459123530254], Predicted Digit = 6, True Digit = 6
# Test Sample 22: Confidence Scores = [-0.9768420560843574, -1.1753119749356171, -0.9906569697001735, -0.8925562268509841, -0.24065444908585074, -0.5316638727229759, 0.38077235157163253, -0.781547747208866, -1.0078017318537957, -1.0190317705515683], Predicted Digit = 6, True Digit = 6
# Test Sample 23: Confidence Scores = [-1.0322726225265622, -0.9637385456114139, -1.302537973333488, -1.1243067065424495, -0.47930978835489957, 0.32170197070106943, 0.09199720986089999, -1.1991798321336142, -0.5907821996405805, -0.26108661242765907], Predicted Digit = 5, True Digit = 5
# Test Sample 24: Confidence Scores = [-0.9428797404009774, -0.9887559768509352, -0.3725423237452123, -0.45437931483454574, 0.27663484284514, -0.6148110222244509, -0.46018323405881256, -0.3375790255329692, -0.4819731820958692, -0.18091101406061078], Predicted Digit = 4, True Digit = 4
# Test Sample 25: Confidence Scores = [1.1580977310969698, -1.2740141334750836, -1.6552438905673819, -0.1766345690385506, 0.0070882846360438775, -1.8190016403391123, -0.6764002909130754, -1.072084922606888, -0.209628390132476, -0.4071497913870761], Predicted Digit = 0, True Digit = 0
# Test Sample 26: Confidence Scores = [-0.8801968412639736, -0.7797582841810894, -0.693838883936331, -0.9750970134862844, -0.6236316749669965, -0.37527493424651226, -0.904673742739001, 0.8778631728187055, -1.579439711280411, -0.3571317428276648], Predicted Digit = 7, True Digit = 7
# Test Sample 27: Confidence Scores = [-1.0471668681917279, -1.039957311179096, -1.2242761790251042, -1.3772279526404476, 0.964620071530546, -1.3275688624685342, -1.288249847485666, -1.3033992471911604, -1.1393832964662458, -0.23008153421248195], Predicted Digit = 4, True Digit = 4
# Test Sample 28: Confidence Scores = [1.3981706569378933, -0.8127207035423676, -0.2835930545025529, -1.6082400234441332, -1.0707342388929237, -1.6806661959346663, -1.0386295815427868, -1.2327136496891675, -0.9222336117275418, -0.3509635761091832], Predicted Digit = 0, True Digit = 0
# Test Sample 29: Confidence Scores = [-0.8408674502815711, 0.1642500673770387, -0.5841165329503638, -1.4306279615150315, -0.016219132257401132, -0.2512619844949379, -0.30720826704862125, -0.8611407371165498, -0.5907506638219198, -0.6331643323375042], Predicted Digit = 1, True Digit = 1
# Test Sample 30: Confidence Scores = [-0.7411571077434487, -1.2542554870672655, -0.7763487881102998, 0.48769708785481813, -0.10410062653058572, -1.0510374028468628, -0.2898236040824743, -0.5504868316230446, -1.4155623021683454, -0.2292204979354553], Predicted Digit = 3, True Digit = 3
# Test Sample 31: Confidence Scores = [-0.43162702701251665, 0.17394752190306365, -0.33836480652278944, -0.9129351785005508, 0.03225496969409132, -0.3723030138300454, -0.16235732220270063, -0.6604612443507268, -0.2731051742455945, -0.22969492112770165], Predicted Digit = 1, True Digit = 1
# Test Sample 32: Confidence Scores = [-0.87245057336423, -0.6985427600053271, -1.118068012888182, 0.9800834484317801, -1.1857904665800822, -0.9284564489953788, -1.7637999072932293, -0.9724253393509035, -0.5933519634967165, -0.7546039184152706], Predicted Digit = 3, True Digit = 3
# Test Sample 33: Confidence Scores = [-0.12176708981907332, -1.4266833065347804, -1.0594516358343429, -0.5533513926840986, -0.26536429125785993, -1.185827370829475, 0.059030916989611985, -0.8813814686518855, -0.9276538639465538, -0.9730585799501256], Predicted Digit = 6, True Digit = 4
# Test Sample 34: Confidence Scores = [-0.9132616853729788, -1.097169261258564, -0.9026045224239123, -1.1996182642008182, -1.7699711798326485, -1.4896478171188394, -0.9275999399295649, 0.9753852687435434, -1.121992976071861, -0.24028243752695821], Predicted Digit = 7, True Digit = 7
# Test Sample 35: Confidence Scores = [-2.559449429410688, -0.8738283783725622, 0.24876034418239884, -0.027702382503266402, -0.8546117719054964, -0.9546032866461185, -0.8668796301646573, -1.2931669745290566, -1.1247211583143595, -0.44159053888862837], Predicted Digit = 2, True Digit = 2
# Test Sample 36: Confidence Scores = [-0.9532553339095889, -0.771033988316409, -0.6447521985572026, -0.18672552582250837, -0.765789809625676, -1.4848409221474808, -1.0282344545067834, 0.48598402462454143, -0.4236351384838233, -0.22151351586663193], Predicted Digit = 7, True Digit = 7
# Test Sample 37: Confidence Scores = [-0.8432284613056629, 0.41057344576679355, -0.7415947789676661, -1.6354443557937215, -0.11593836695091145, -0.4606675760324364, -0.696659803179983, -0.6975381177897994, -0.6844926919191512, -0.5816975243854622], Predicted Digit = 1, True Digit = 1
# Test Sample 38: Confidence Scores = [-1.0654218602364474, -0.8835437324899685, 0.05065368281689153, -0.3217206611647955, -1.56956770411916, -0.5635659021055509, -0.5897612587151593, -1.0579559344139993, -0.3357165450727624, -0.4915554539205799], Predicted Digit = 2, True Digit = 2
# Test Sample 39: Confidence Scores = [-0.9924386109833613, 0.7428524224226685, -0.9344340876372602, -1.6502535868396069, -0.4895552790480593, -1.5163577236550154, -0.6139285627469407, -0.87047400175335, -1.3628702429358905, -1.1260650475508034], Predicted Digit = 1, True Digit = 1
# Test Sample 40: Confidence Scores = [-1.1143559721137315, 0.19964686872833773, -0.5163280060725021, -0.9005640138978669, -0.3720488691982818, -0.16091213391954037, -0.09908431954996914, -0.5224546887765588, -0.4622210680446682, -0.08566344045396633], Predicted Digit = 1, True Digit = 1
# Test Sample 41: Confidence Scores = [-1.0464023428853424, -0.844460589377625, -0.28142824920134624, -0.3962916444025894, -0.5809496724986374, -1.3168002828061494, -1.1316121806452015, 0.2727402583944767, -0.512440073805712, -0.4012814422152931], Predicted Digit = 7, True Digit = 7
# Test Sample 42: Confidence Scores = [-0.8731837006044534, -0.6937873941122146, -0.9276573451605393, -1.2253476996092993, 1.1285900043512542, -1.5833198428549715, -1.1394937475354177, -0.9070888731785622, -1.0050920050450776, -0.9208810575681966], Predicted Digit = 4, True Digit = 4
# Test Sample 43: Confidence Scores = [-1.1099971574943062, -0.8106646583864164, 0.400506048231353, -1.2280511734603836, -0.3720084447591411, -0.033713930632544804, -0.09693718287991229, -0.8551237196716729, -0.8222035018221933, -0.8983466567679678], Predicted Digit = 2, True Digit = 2
# Test Sample 44: Confidence Scores = [-0.6597787473347584, -0.788313251032739, -0.4321507323526995, -0.5205842560420607, -0.41639394417293324, -0.1391630129793549, -0.1980495891436736, -1.0712381454564066, -0.8452966232841942, -0.39257023370612737], Predicted Digit = 5, True Digit = 3
# Test Sample 45: Confidence Scores = [-0.7136911484408941, -1.161069392204893, -1.230344118484321, -0.8912558048325651, -0.2760674986084183, 0.21911075818405606, -0.46507194723671447, -1.1444904942981435, -0.40616788077692, -0.3223247846598884], Predicted Digit = 5, True Digit = 5
# Test Sample 46: Confidence Scores = [-0.6033613722265045, 1.434735946495728, -0.5200817357358588, -0.9827840565821118, 0.08258926085202878, -1.3745085132389716, -0.5018641095507314, -1.0429431354323997, -0.4317032333310313, -0.2720868056475441], Predicted Digit = 1, True Digit = 1
# Test Sample 47: Confidence Scores = [-0.9218134458934205, -1.03162196775549, 0.21208017118307626, -0.750941020354478, 0.0018064541273963616, -0.5596114635022507, -0.44362233477916135, -0.5799480870128727, -0.46244364514028924, -0.4712274381704588], Predicted Digit = 2, True Digit = 2
# Test Sample 48: Confidence Scores = [-1.011034056038088, -0.9392762399813587, -1.5399744657643712, -2.5904735607420393, 1.1815733384718388, -1.681000129423394, -1.6318210163457576, -1.371541340393151, -0.5872328055482079, -0.4786096802346169], Predicted Digit = 4, True Digit = 4
# Test Sample 49: Confidence Scores = [-1.262026898884117, -1.0644029691628143, -1.2838506391013478, -1.6652806034663878, 0.34522080261278437, -1.3430700421707167, -1.6019295683292596, -0.43853901870245215, -1.27260372914944, -0.23641697061158237], Predicted Digit = 4, True Digit = 4
# Test Sample 50: Confidence Scores = [-0.7156740549988131, -1.1772813240384512, -0.9548596328065648, -1.5905122579287585, -0.5227318279936242, -0.5609759433730193, 0.7677507776454334, -0.8810052407801757, -1.2683566135461717, -0.2893441499741496], Predicted Digit = 6, True Digit = 6
# Test Sample 51: Confidence Scores = [-1.0854993391061505, -1.1253124208188943, -0.486503668458586, -0.376620290233342, -1.404508571347724, -1.158967387247791, -0.3797592200162476, -0.8791251859068779, -0.17897382447366922, -0.1265755660656422], Predicted Digit = 9, True Digit = 3
# Test Sample 52: Confidence Scores = [-0.812666201025562, -1.1961232462352391, -0.8368855794382313, -0.721122689425457, -0.5730884576996947, 0.1842597183883193, -0.5055521705033246, -0.917207622417402, -1.049097360860425, -0.09873368559300685], Predicted Digit = 5, True Digit = 5
# Test Sample 53: Confidence Scores = [-1.172673784075886, -1.1832028836320514, -0.6237488656866679, -0.03625148202016765, -0.45243466985784164, 0.10480463271324364, -0.4951649930300704, -0.525983774547551, -0.1621799705784798, -0.3474700309610948], Predicted Digit = 5, True Digit = 5
# Test Sample 54: Confidence Scores = [-0.691833329496288, -1.0780197736152508, -0.3853846651900091, -1.3344697861762622, -0.14041802158004052, -0.2777392427579091, 0.3161670944181937, -1.2298186747039186, -0.4835965384793842, -1.0658851692656501], Predicted Digit = 6, True Digit = 6
# Test Sample 55: Confidence Scores = [0.8064430282120995, -0.8883869947076802, -1.395709029041751, -1.6607134533086438, -0.9592529738047445, -1.2752780023004628, -0.3743573199764383, -1.2604028171680506, -0.727250103559795, -0.17462040816534183], Predicted Digit = 0, True Digit = 0
# Test Sample 56: Confidence Scores = [-1.1120613918508562, -0.9394358976737848, -1.1650858381208125, -1.2090941633876204, 1.1124492439576612, -1.595139991729848, -1.9716428227494462, -1.0412017748879006, -0.6914354785246961, -0.4515810674521514], Predicted Digit = 4, True Digit = 4
# Test Sample 57: Confidence Scores = [-1.161463959126455, 0.3466549891192947, -0.5459353845078855, -0.8967840125606003, -0.4337577311892185, -0.6802236424799059, -0.3955512219652424, -0.47947514784070405, -0.9427238474764764, -0.43892342765938147], Predicted Digit = 1, True Digit = 1
# Test Sample 58: Confidence Scores = [-1.1446361550081658, -1.170013535994017, -1.280242003973103, -1.428046516791485, -0.1622188900713183, -0.655950006425908, -1.860909573491891, -0.13467270580810298, -1.4502170556958396, 0.20298663626823865], Predicted Digit = 9, True Digit = 9
# Test Sample 59: Confidence Scores = [-0.7643532819888029, -0.6772965790464769, -1.0932025065280642, -0.6846532049258754, -0.6625459531454164, 0.0013892741252973567, 0.17991619415000798, -0.0619913731245171, -0.837677027107469, -0.11598290372794727], Predicted Digit = 6, True Digit = 5
# Test Sample 60: Confidence Scores = [-1.0526039800919522, -1.0906396690873816, -1.2183977050426702, -1.0703221402997167, -0.13554848497918626, -0.9219581598319988, -1.4257680578222516, 0.3952080339986952, -1.418712210331999, -0.1700303266967854], Predicted Digit = 7, True Digit = 7
# Test Sample 61: Confidence Scores = [-1.0078512614405386, -1.106967110608349, -0.7147995390457229, -0.5328734978330856, -0.47905460590355536, -0.12017040617280988, -1.797522398658141, -0.7965233607528277, -0.3162651428071769, -0.6229561475309561], Predicted Digit = 5, True Digit = 8
# Test Sample 62: Confidence Scores = [-0.9612152618534735, -0.7230109898200757, -0.3826841105254481, -0.6159936072329744, -0.10954270065674597, -0.5941657035004332, -0.5491838523102356, -0.6438100580849656, -0.07033635441016613, 0.0015946147079899], Predicted Digit = 9, True Digit = 9
# Test Sample 63: Confidence Scores = [-0.9666465941926141, -1.0621035227270712, -0.4109124493570506, -0.8522397550809437, -0.6558139641867335, -0.7268081904689067, -1.2690166229110695, -0.6663204465422251, -0.5831868676353388, -0.9410965301025436], Predicted Digit = 2, True Digit = 3
# Test Sample 64: Confidence Scores = [-1.1075933485461749, -1.2437173930333807, -0.5496671287788932, -0.7121760266082521, -1.00095782621508, -1.3474697320317026, -1.3033327850585055, 0.2335738710497064, -1.282818096158353, 0.08941971246873848], Predicted Digit = 7, True Digit = 7
# Test Sample 65: Confidence Scores = [-0.943567464828235, -0.6287228325273236, -0.9091283477628553, -0.9398551236388348, 0.30828827649667373, -0.23516445275936548, -0.9309688156250142, -0.8821686124671, -0.22875633217516586, -0.05989941332318063], Predicted Digit = 4, True Digit = 4
# Test Sample 66: Confidence Scores = [-1.1367444899158223, -1.2750092230800378, -1.1051315271727515, -0.44973760363729975, -0.12792302483405601, -0.40360834347254826, 0.16655337229313616, -0.8007527742750756, -0.6076949247910095, -1.098400096967259], Predicted Digit = 6, True Digit = 6
# Test Sample 67: Confidence Scores = [-1.0430434836040199, -1.0026931659491565, -0.6419179074475584, -1.216454089318801, 0.4167921247136795, -0.8618081589006077, -1.5998658143543396, -0.8737395728908556, -1.0863150190587028, -0.29325936853998674], Predicted Digit = 4, True Digit = 4
# Test Sample 68: Confidence Scores = [0.28921397858854286, -0.6821060646646375, -1.1164958868264576, 0.22417639181306445, -0.18640824482611984, -2.0765637664891696, -0.6342273659663297, -0.8485232335369682, -0.08925660940520996, -0.5931671906092939], Predicted Digit = 0, True Digit = 3
# Test Sample 69: Confidence Scores = [0.813446770096114, -0.8930172015985209, -0.499425983284459, -0.44389940138856515, -0.43469474924725987, -0.9645344107351176, -1.5638632463153723, -0.5702387409641195, -0.9067629750178776, -1.0431492783235812], Predicted Digit = 0, True Digit = 0
# Test Sample 70: Confidence Scores = [-0.4859281531075504, -0.9163641978077862, -0.7283206692600948, -0.6051818028414053, -1.4822796067986013, -1.5059131082840254, -1.046051888807115, 0.9514349341305055, -1.0148670291293653, -0.43351828358671923], Predicted Digit = 7, True Digit = 7
# Test Sample 71: Confidence Scores = [0.7905060920426239, -1.1132425270967656, -1.6764013708100718, -0.7584715189890298, -0.3513025205199117, -1.2482425899905036, -0.6060739615965278, -0.9956436100803037, -1.3968742499922047, -0.790383943372972], Predicted Digit = 0, True Digit = 0
# Test Sample 72: Confidence Scores = [-1.0898621765249372, -1.3209344746135958, -0.0592672010091291, -0.4544533630241536, -2.089200141376671, -0.9965449391301239, -1.4763067488524355, -1.2943132451725794, -0.5311663341443388, -0.4473082237565826], Predicted Digit = 2, True Digit = 2
# Test Sample 73: Confidence Scores = [-0.914295165081354, -1.0793847489116541, -1.1135630944455164, -0.6595045968144506, -0.9135989056732883, -0.777747328590969, -1.2383507513057839, -0.40720927932244255, -1.4105853885947819, 0.09260787305478016], Predicted Digit = 9, True Digit = 9
# Test Sample 74: Confidence Scores = [-1.1118030852592058, 0.6385991627259432, -1.015068435685123, -1.9106333958140098, -0.32980011036168777, -0.5116347242417556, -0.9513161266965183, -0.714448627536147, -0.9766893602301482, -0.5589144154292884], Predicted Digit = 1, True Digit = 1
# Test Sample 75: Confidence Scores = [-0.6206129935168901, -0.6946218710885865, -1.1272307841538105, -0.6904848246736187, 0.0955291756486319, -0.618052370329266, -0.9046681499975441, 0.12339269693116126, -0.8611795023344518, -0.40817334236653197], Predicted Digit = 7, True Digit = 7
# Test Sample 76: Confidence Scores = [-0.5719761827549513, -1.2073344267234563, -0.8657371172258729, 0.09089647104762862, -0.3873529270664687, -0.434900669215715, -0.24143247685579539, -1.030290101741781, -0.25088148393132376, -0.3350700130751734], Predicted Digit = 3, True Digit = 3
# Test Sample 77: Confidence Scores = [-0.6567379428483122, -0.9411668392612674, 0.2816657876388841, 0.05617553373633846, -0.9424596105139077, -0.9654617758245223, -0.3436548780657495, -0.37910367027938596, -0.762079619534838, -0.1625455153010355], Predicted Digit = 2, True Digit = 2
# Test Sample 78: Confidence Scores = [-0.691434526437752, -0.9028758586612329, -1.280379339664044, -0.8132530942496529, 0.005731804628012165, -0.7807165632957658, -0.6262110587794525, -0.8687693723066895, -1.100114092690451, 0.26983795124672294], Predicted Digit = 9, True Digit = 9
# Test Sample 79: Confidence Scores = [-1.0723066050525796, -1.021424747306784, -0.90592110050941, -1.397800041098438, -1.865123886102671, -1.8839701458725022, -2.2924228546318264, 1.459909796244441, -1.805478293726129, -0.8545731887265782], Predicted Digit = 7, True Digit = 7
# Test Sample 80: Confidence Scores = [-1.1749505808878087, -0.6706111902775462, -0.4222818328164431, -1.2459090126071648, -0.7062790898257841, -0.6760261877636347, -1.7109983234460573, -0.6216977995083299, -1.2974293485474, -0.005665101508474023], Predicted Digit = 9, True Digit = 7
# Test Sample 81: Confidence Scores = [-0.6074158358121149, -0.8845613004978778, -1.205911258686676, -1.0555252110257516, -1.241795127996381, -0.33745337018491284, 0.22284734283095162, -0.9498426577055757, -1.1482250833887184, -0.6391163961397489], Predicted Digit = 6, True Digit = 6
# Test Sample 82: Confidence Scores = [-1.7100475746779282, -1.147835983328872, 0.9738363379381565, -1.7041132819730815, -0.9879647505788008, -0.5010421225869693, -1.9001776891507836, -1.005134125766311, -2.131764830572592, -1.166521311952441], Predicted Digit = 2, True Digit = 2
# Test Sample 83: Confidence Scores = [-1.2630128447602489, -0.5990193020020057, -1.029565712418402, -1.1010691440606113, -0.8271148681336952, -1.0228384310990593, -0.9685503048381935, 0.4407660918768168, -1.2257271646585084, -0.0650732717557929], Predicted Digit = 7, True Digit = 7
# Test Sample 84: Confidence Scores = [-1.1402556729643583, -0.8723035179315307, -0.3138011580557731, -0.8644071200289241, -0.4290076294268194, -0.7990166861734285, -0.4598201606765449, -1.049748826615674, 0.601603487402767, -0.6189128588577774], Predicted Digit = 8, True Digit = 8
# Test Sample 85: Confidence Scores = [-1.0373980907950544, -0.9487442733215231, -1.2975043319543806, -2.045956136247051, 1.2396084929439652, -1.3254027670806159, -2.131735136366331, -0.9340189808600096, -0.4223612545767388, -1.0080128585138728], Predicted Digit = 4, True Digit = 4
# Test Sample 86: Confidence Scores = [-0.9387661689546961, -0.9863169638166919, -0.5401514045457486, -1.431260735618197, -1.3411653219248598, -1.5326705957095124, -1.3958593103752168, 1.1312405442090396, -1.0683311214621642, -0.34432909863091454], Predicted Digit = 7, True Digit = 7
# Test Sample 87: Confidence Scores = [-0.9613777792176204, -1.257109939022647, -0.8847129363733113, 0.02859234559204746, -0.8553665869650767, -0.2539766342781652, -1.1182111677860798, -0.19770404637424388, -0.5767331609463578, -0.3580432133054238], Predicted Digit = 3, True Digit = 3
# Test Sample 88: Confidence Scores = [-0.769551239997344, -1.8600412044555865, -1.1750693071040734, -0.7062951115651956, -0.07822394460839503, -1.1056930902020743, 0.8164496629218448, -0.6035481802867259, -1.009351958849609, -1.4995699585224387], Predicted Digit = 6, True Digit = 6
# Test Sample 89: Confidence Scores = [-1.2050972857859357, 0.44744006433380373, -1.2345865253525137, -1.5297737759941197, -0.22653084660037512, -1.1867458734764547, -0.6538665938122985, -0.7265580351521723, -1.6354614432588255, -1.1204103778858554], Predicted Digit = 1, True Digit = 1
# Test Sample 90: Confidence Scores = [-0.5306024199374753, -1.2417859407676124, -0.9692477970783638, 0.2945088067130489, -0.42986091733857607, -0.24423219690910203, -1.033317179086475, -1.1939483599607585, -0.6346905603318512, -0.3752845402632367], Predicted Digit = 3, True Digit = 3
# Test Sample 91: Confidence Scores = [-1.02466751554788, -1.128795084363296, -1.4259771081676236, -0.8450297598103026, -0.9425388811648111, -0.8528991749216049, 1.133606157550433, -0.9864542296055964, -1.0850977863400872, -0.7511282810029764], Predicted Digit = 6, True Digit = 6
# Test Sample 92: Confidence Scores = [-1.057290883783101, -0.9315344091643659, -1.1948268404286533, -1.0507966470280625, -0.14930766962004752, -0.31176345414290624, -0.4127639136954551, -0.7740085097130972, -0.3883383178588182, 0.0006383388814219796], Predicted Digit = 9, True Digit = 9
# Test Sample 93: Confidence Scores = [0.022826594712154046, 0.9947066033217883, -1.1190150085434851, 0.06138672312201025, -0.04485986744389487, -1.299777431251972, -1.2849447095060536, -1.3157014453813858, -1.2126200246064214, 0.07448823134355678], Predicted Digit = 1, True Digit = 3
# Test Sample 94: Confidence Scores = [-0.22682907564319227, 0.5767947318825701, -0.6915206771468986, -2.7396966239934337, -0.12697339438376715, -1.3917971269402714, -0.5728257065420397, -0.7770324296189616, -0.7536992068494144, -1.4567675659534582], Predicted Digit = 1, True Digit = 1
# Test Sample 95: Confidence Scores = [-0.6564211054989108, -1.1322833018907783, -1.2698692626352308, -1.5313924977369318, 0.6726857771988237, -1.1524866258269504, -0.636969361446579, -1.1725264619228601, -1.3780819014410206, -0.7698961600597547], Predicted Digit = 4, True Digit = 4
# Test Sample 96: Confidence Scores = [-0.7150246347089777, 0.5267349040879793, -0.471355697401347, -0.8461845440508523, -0.03873707569038145, -0.4655006270184298, -0.13403666488452437, -0.7288656598839687, -0.21219308011857788, -0.10033626808730699], Predicted Digit = 1, True Digit = 1
# Test Sample 97: Confidence Scores = [-1.5383602555106095, 0.4116019469834241, -0.336120329255246, -0.9425137628024902, -0.47340633261302945, -1.514486817597477, -1.159259166029073, 0.15522814951700276, -2.1934790058948472, -0.4110168250772415], Predicted Digit = 1, True Digit = 7
# Test Sample 98: Confidence Scores = [-1.2743257487943687, -1.012872911150659, -0.8353701836639617, -0.3619970741614067, -1.2093350636395408, -0.38784896160354093, 0.6426057217404408, -0.8269776721338685, -0.8280912770018211, -0.4830809987198028], Predicted Digit = 6, True Digit = 6
# Test Sample 99: Confidence Scores = [-1.2896722341803193, -1.1865763916922105, -1.382712383210707, -0.5768273153711592, -0.8072333226853623, -0.8060868120441449, -1.4952045191577041, -0.8515872855795156, -1.303743452033261, 0.3173326627618043], Predicted Digit = 9, True Digit = 9
# Test Sample 100: Confidence Scores = [-0.984857446109184, -1.196713339424056, -0.5701553356140604, -0.8300827955690462, 0.09708022344874688, -0.4958740505584971, 0.4556081472849441, -0.7782003664906314, -0.2156690550974585, -0.7402843391088223], Predicted Digit = 6, True Digit = 6
# Test Sample 101: Confidence Scores = [0.5666851372551363, -0.7610246041341657, -0.5290929129300342, -0.8395080423775563, -1.3434835071429672, -0.6158867185775924, -0.7752028432855792, -0.6720561278898063, -1.1614786434937674, -1.1230142740838212], Predicted Digit = 0, True Digit = 0
# Test Sample 102: Confidence Scores = [-1.1792545244691144, -1.0635341303486854, -1.1422117221062897, -0.03167709085538226, -0.3172614240295394, 0.04781675478497836, -0.9330140407702409, -0.622295730823031, -0.7892672399428978, -0.2927620877593148], Predicted Digit = 5, True Digit = 5
# Test Sample 103: Confidence Scores = [-1.2851094522317386, -1.0418806242393557, -1.0357190611764409, -1.2416212448139106, 0.4885198644206596, -0.914788726560636, -1.718521008673499, -0.71875033750437, -1.2925271241288459, -0.22162926436350922], Predicted Digit = 4, True Digit = 4
# Test Sample 104: Confidence Scores = [-1.1315623772932466, -1.1726720372312074, -0.8761964169424026, -0.562708219087252, -0.02679253548094268, 0.08433044363004831, -0.6040365091909324, -1.0786217756032024, -0.7307468650809416, 0.17528109987814744], Predicted Digit = 9, True Digit = 9
# Test Sample 105: Confidence Scores = [-1.2421751203033398, -1.0330403789290528, -0.8586587891971912, -0.764617336936165, -0.5978433197368446, -0.8622782426117388, -1.2854091913852195, -0.5355096796637163, -1.1868385544456237, 0.31166915884326707], Predicted Digit = 9, True Digit = 9
# Test Sample 106: Confidence Scores = [-1.4668524985173685, -1.1871683405722795, 0.7244679526014018, -1.1122462926799983, -1.4819279508733076, -0.6086402866548671, -0.8203752434904613, -1.0930465282754966, -0.33869724084724123, -0.8754833583524022], Predicted Digit = 2, True Digit = 2
# Test Sample 107: Confidence Scores = [-0.888832726701369, -0.08822448271148467, -0.7783809102933729, -1.3368616005226999, -0.38452221596508573, -0.6622774988137625, 0.35279437834344257, -0.5978343835879664, -1.0129476305152223, -0.996597155810819], Predicted Digit = 6, True Digit = 1
# Test Sample 108: Confidence Scores = [-1.1878307008854498, -0.4619723916963117, -1.075184779963135, -1.5227930084900962, -0.12303661695198125, -1.7499584553959573, -1.306807850697873, -1.48885847898996, -0.5529461554420635, 0.2022244665826679], Predicted Digit = 9, True Digit = 9
# Test Sample 109: Confidence Scores = [-0.5823191805244845, -1.2377745595778293, -0.9025240582493733, -1.8586907147800926, 1.1363067901082187, -1.5527955693332627, -0.5309741132694913, -0.6460251649230985, -0.7090253456640419, -0.5028276639777659], Predicted Digit = 4, True Digit = 4
# Test Sample 110: Confidence Scores = [-0.6727188022768489, -1.322437456805527, -1.8205866291036084, -1.3536726453531922, -0.1115361665550808, -0.5962087346938681, -0.7690686401918364, -1.0792604655139346, 0.1480132049889862, -1.4531446742974403], Predicted Digit = 8, True Digit = 8
# Test Sample 111: Confidence Scores = [-1.1627656449002637, -0.24261367843453252, -0.592521002330224, -1.3580512149800086, -0.5599500661350528, -1.2742244175523578, -1.7581146464485746, 0.294223542509376, -0.8135375486918607, -0.2812931564020581], Predicted Digit = 7, True Digit = 7
# Test Sample 112: Confidence Scores = [1.187602193639095, -0.4657277846584723, -0.6264004169883957, 0.1337873571177938, -0.4610466613188097, -0.8149758934390077, -0.3552920496609749, -1.0075632733800368, -0.5973842761454254, -0.5093785748146554], Predicted Digit = 0, True Digit = 3
# Test Sample 113: Confidence Scores = [-1.187264558016827, -1.0734774893377765, -0.6972173252231659, -1.0370957069310696, -0.9076465423035059, -1.2428114929506398, -1.4370816037277634, -0.8588700059679432, -0.7206701398070194, 0.3270594581010351], Predicted Digit = 9, True Digit = 9
# Test Sample 114: Confidence Scores = [-1.0805373994431868, -1.0186468453585684, -0.1507890733425346, -0.5624240006681684, -1.043840984795817, -0.6939855451233119, -1.1693909857260891, 0.31004284852874475, -0.6470807164196248, -0.12248012102613758], Predicted Digit = 7, True Digit = 7
# Test Sample 115: Confidence Scores = [-0.6925601419124399, -0.9864741183636382, -1.296486785198525, -2.1713022673211495, 0.6971375480631954, -0.8784020466135158, -0.5880058343795037, -0.6868710197703048, -0.8299780423824171, -0.2234568046481056], Predicted Digit = 4, True Digit = 4
# Test Sample 116: Confidence Scores = [-0.9162107617429206, -0.7767007741445168, -0.8465337068882886, -1.6123563807263266, 0.6863629712726387, -0.9548915803495597, -0.9036552842883223, -1.030290108240207, -0.2408650325518538, -0.4810794943212617], Predicted Digit = 4, True Digit = 4
# Test Sample 117: Confidence Scores = [-1.2166054391134096, -0.9755940202235529, -0.0663863906691735, -1.0183151011481724, 0.7801694075461503, -1.665467650947454, -2.2768241747045495, -1.1186758315272276, -1.4502431278493517, -0.8611595625791933], Predicted Digit = 4, True Digit = 4
# Test Sample 118: Confidence Scores = [-0.7789006607127416, -0.8222940742813549, -0.6912198527664528, -1.610291603049756, 0.025906659248187254, -1.0172371130383804, -1.0218389380803548, -0.4285500671425904, -0.8874238139024473, 0.16166261869258833], Predicted Digit = 9, True Digit = 9
# Test Sample 119: Confidence Scores = [-1.32314955485173, -0.8917615913276106, -0.03183112748725545, -0.3781119051263744, -1.808458915484885, -1.1258472216499216, -1.0593073752904547, 0.030159510469734686, -0.6003308046865462, -0.18585507179993185], Predicted Digit = 7, True Digit = 2
# Test Sample 120: Confidence Scores = [-1.019323403096395, -0.9991583592390443, -1.34001520538244, -0.2046850502446643, -0.8324294705034184, 0.7217663981924345, -0.9762258840334083, -0.8818519962114492, -0.7124270706600427, -0.5592305725666548], Predicted Digit = 5, True Digit = 5
# Test Sample 121: Confidence Scores = [-0.9589861793828525, -0.8794473262808257, -1.7238399577541792, -1.6464158143812035, -0.04372224134805263, -1.346508051068659, 0.018731283057915934, -0.7916741694215667, -0.9262921503491727, -0.5000105040492049], Predicted Digit = 6, True Digit = 4
# Test Sample 122: Confidence Scores = [-0.8505753628270042, -0.052219125180212204, -0.7841922453062021, -0.20379820232436435, -0.1516124187865032, -0.957329454988626, -0.5832874016273615, -0.46023803848726563, -0.4749958548376645, 0.21255499619386417], Predicted Digit = 9, True Digit = 7
# Test Sample 123: Confidence Scores = [-0.5351311634936876, -1.3379868425337889, -1.2325797393878106, -0.7943788050587457, -0.43132035967713245, -0.7287352938874598, 0.5648140207032417, -0.921067376344036, -1.0225374518084316, -0.9992376252100861], Predicted Digit = 6, True Digit = 6
# Test Sample 124: Confidence Scores = [-0.866913626107032, -1.5188418282063951, -1.2263714649176474, -1.8330255942684943, 0.8441991338609774, 0.13440001371567956, -0.6611672369339442, -0.4571682288468158, -0.9114426722906657, -1.0246491101151414], Predicted Digit = 4, True Digit = 7
# Test Sample 125: Confidence Scores = [-1.0082672880711245, -1.0390498090958966, -0.4287613281971773, -0.7091953165280296, -0.2554987658436019, -0.7464958939484675, -0.7599212737722771, -0.8731434636000541, -0.3116559228764725, 0.03822235456483184], Predicted Digit = 9, True Digit = 9
# Test Sample 126: Confidence Scores = [-0.20491358270664345, -1.2797021771850783, -1.0175193207537878, -0.03397573970116716, -0.623650739040802, -0.9283141043180492, -0.260943214269523, -1.1959941397541944, -0.32986165495609293, -0.11485674316514999], Predicted Digit = 3, True Digit = 0
# Test Sample 127: Confidence Scores = [-1.089305369643149, -1.1938815418329882, -1.055166681520712, -0.6949738545628592, -1.5406898415681407, 0.7443882187197557, -0.8870901179326874, -1.2835108444804175, -0.6140035859192987, -0.13129630582569488], Predicted Digit = 5, True Digit = 5
# Test Sample 128: Confidence Scores = [-1.3534409076897491, -0.9190001171452431, -0.7712671390452996, -1.3626597788593309, -1.0540227173432783, -1.463363674681489, -1.1416060605274292, -0.7930539418053923, 0.30045023638945834, -0.3774752593789501], Predicted Digit = 8, True Digit = 8
# Test Sample 129: Confidence Scores = [-1.2940680226865953, -0.987954784033807, -1.2542911945158792, -0.6620131730183024, -0.614535087811937, 0.4766115513800977, -0.7048444151217107, -1.0685047160324261, -0.45234971973976823, -0.12943291510091784], Predicted Digit = 5, True Digit = 5
# Test Sample 130: Confidence Scores = [-1.0849150938447754, -1.0556214142974194, -1.9812761917318027, -0.8069385645150301, -1.650443350414124, -0.7302051539307118, 1.3144472394190678, -1.1038137254137188, -1.340331779097697, -0.7412431235826523], Predicted Digit = 6, True Digit = 6
# Test Sample 131: Confidence Scores = [-1.4133587521459703, -1.0598804907022166, -1.9535270934474358, -0.876449233866435, -1.5326606530548428, -0.31578339198120947, 1.7386025783346242, -1.1584897375851577, -1.026378182907522, -0.6865585165763881], Predicted Digit = 6, True Digit = 6
# Test Sample 132: Confidence Scores = [-1.1855369499197845, -0.8526060254953717, -1.473242552222068, -0.5501088072577139, -1.1505194977264437, 0.943655869002703, -1.031809695893015, -0.8443506916795821, -0.25276948196681304, -0.5055371986676607], Predicted Digit = 5, True Digit = 5
# Test Sample 133: Confidence Scores = [-0.809707478320054, -0.928165850168726, -0.7402100728381589, -0.7214812742798407, -1.368506878764379, -1.0558145687329485, -2.453897340205164, 0.4666127878050819, -0.5409900743512135, -0.10581102945804026], Predicted Digit = 7, True Digit = 7
# Test Sample 134: Confidence Scores = [-1.0825803677882584, -1.0118667732753086, -1.8862155062631316, -2.3620161379117777, -1.184577948791534, -0.5687015647299105, -1.0518654533152383, -0.7802826239012685, 0.4398282320270219, -1.1638901857811754], Predicted Digit = 8, True Digit = 8
# Test Sample 135: Confidence Scores = [-1.0971062073801408, 0.8645254504767559, -0.8840165878585325, -1.86632560981305, -0.6432234283728131, -1.1505457273710369, -1.0985632002084431, -0.8525358700001178, -1.405541975043992, -1.0282644611291438], Predicted Digit = 1, True Digit = 1
# Test Sample 136: Confidence Scores = [1.3818640380921432, -1.097736209406352, -0.8723485914559149, -1.7804616235672497, -1.36345140516135, -0.7058107322407485, -0.7533550069767143, -1.1329405751438788, -1.1231122258273891, -0.12532518455143105], Predicted Digit = 0, True Digit = 0
# Test Sample 137: Confidence Scores = [-1.151339669343358, 0.3846160422830056, -1.0423152577993116, -1.9530219656192063, -0.18628033381192693, -1.6490520335188084, -0.3750220436447605, -0.6768722499720572, -1.4895032346156731, -1.2448726919455486], Predicted Digit = 1, True Digit = 1
# Test Sample 138: Confidence Scores = [-0.6250549873491092, -1.690142604674593, -1.4216099596234204, -0.05303636330489618, -0.41441017765542276, -0.9149747839563707, 0.9371513849790356, -0.8133872013583459, -1.0524313563716778, -1.2978062953069263], Predicted Digit = 6, True Digit = 6
# Test Sample 139: Confidence Scores = [-1.0126766313022406, -1.0090427493048704, -1.878187892702882, -1.7867208441573053, 0.18543011637139348, -1.3512894144881014, -1.1503391715713542, -0.9315886917501055, -0.28948944459213366, -0.5863384319547091], Predicted Digit = 4, True Digit = 4
# Test Sample 140: Confidence Scores = [-0.789816078674663, -0.5804595182411592, -0.6962174931110733, -0.7487586547404345, -0.5083482161268088, -0.5203552237170526, 0.7315866440840132, -0.94235674866413, -0.6190532760495813, -0.07810014049199557], Predicted Digit = 6, True Digit = 6
# Test Sample 141: Confidence Scores = [-0.851905144934483, -0.6023814612312418, -1.0394389776796293, -0.8712285331631815, -0.5709019326124067, -0.6950784318206675, -0.9172881360267489, 0.36855336242290043, -1.3763308844199342, 0.014861788043203806], Predicted Digit = 7, True Digit = 7
# Test Sample 142: Confidence Scores = [-0.3788304447091573, -1.1203600929442359, -0.3217356933796969, -0.12782134227146727, -0.8885083590168246, -0.8251252529962613, -0.752921618996219, -0.8269887780110775, -0.5775265187463317, -0.12724986690358386], Predicted Digit = 9, True Digit = 3
# Test Sample 143: Confidence Scores = [-1.289138898969687, 0.4350979676058369, -0.7586181818068403, -1.3873777211979301, -0.7180632795491704, -0.8096564775615991, -0.4692640698084138, -0.5822733927022802, -0.8951037931547299, -0.4715713018925046], Predicted Digit = 1, True Digit = 1
# Test Sample 144: Confidence Scores = [-1.0493128833458862, -1.1675873450520546, -0.344766066820721, -0.7424909736186271, -1.0002063530121745, -1.0117350435251462, -1.0194812398426185, 0.1059579951454102, -1.0026198157380866, -0.10554239533339954], Predicted Digit = 7, True Digit = 7
# Test Sample 145: Confidence Scores = [-0.7044192122078055, 0.2503126168273014, -0.5285155788162782, -1.2594561556298227, -0.11560229419654623, -0.21577800584370108, -0.22130048279803485, -0.7473960954187502, -0.3900969324287855, -0.4006129423252332], Predicted Digit = 1, True Digit = 1
# Test Sample 146: Confidence Scores = [-1.1573092143774926, -1.0319976083388105, -1.049677578235257, -1.0914350847386864, -1.1356609920531981, -0.4958525356198185, -0.7187916547249058, -1.1434383081882855, 0.8328747401651018, -0.7627023391358301], Predicted Digit = 8, True Digit = 8
# Test Sample 147: Confidence Scores = [-1.5228254087588178, -0.9866517111576169, 0.9512783457062627, -1.1610436152772585, -0.37171230861849847, -1.3717432589094298, -1.7597504823622168, -1.0952255419632075, -1.1735386056917525, -1.5455078553911634], Predicted Digit = 2, True Digit = 2
# Test Sample 148: Confidence Scores = [1.041179952660972, -0.9391153582594047, -0.689670354334384, -1.4248066572214715, -1.5537676760455765, -1.289593742238825, 0.040234463288674596, -1.0327494994370428, -1.17881160745742, -0.35475839195854725], Predicted Digit = 0, True Digit = 0
# Test Sample 149: Confidence Scores = [-1.1990987702743703, -0.8093927992026204, -0.11595886557769455, -0.6085380178370606, 0.03032911710150276, -0.2521182753386252, -0.13805518183486223, -0.6820172737839814, 0.01588863458304539, -0.3219115685448372], Predicted Digit = 4, True Digit = 2
# Test Sample 150: Confidence Scores = [-1.147534847336966, -1.0353290121789773, -1.4342778904901623, -0.6546269584068682, -0.0032169573042030784, -0.7296433611649387, -1.184196065050929, -1.4005436886645608, -1.0612053260697805, 0.20833004525880996], Predicted Digit = 9, True Digit = 9
# Test Sample 151: Confidence Scores = [-0.8225769153617788, -0.9743834910452557, -0.574967788975189, 0.07564680369439748, -0.8107898700100596, -0.8619485510112631, -1.006265724631958, -1.0170996182344865, -0.9399403662972758, -0.25908456373734445], Predicted Digit = 3, True Digit = 9
# Test Sample 152: Confidence Scores = [-0.965838068932428, -0.5817492583388141, -1.1666199012623706, -1.2863350874861614, -0.5002440214434856, -0.2363574538578439, -0.809842265624397, -1.3487341836918556, -1.1654151879714176, -0.009410479290660217], Predicted Digit = 9, True Digit = 5
# Test Sample 153: Confidence Scores = [-0.8297638468766676, -0.7989168446054761, -0.9379588932202672, -0.4825075810065389, -0.5961130273434532, 0.3004459404494631, -0.9637504617048328, -0.8793040261345857, -0.16594980260456138, -0.28988452971511536], Predicted Digit = 5, True Digit = 5
# Test Sample 154: Confidence Scores = [-0.9374634916662468, 0.09059414681594741, -0.5423174810718646, -1.0328685704434342, -0.06856545589311816, -0.24959137640488135, -0.6109881700592075, -0.5022164924120098, -0.39198634788398473, -0.1525240781041953], Predicted Digit = 1, True Digit = 1
# Test Sample 155: Confidence Scores = [-1.0267963013880914, -1.035462046346575, -1.7226835499800746, -0.6121082511309531, -0.08237052606313282, -0.4613292807897938, -0.8930865739100844, -1.468459994825094, -0.9675107722304006, -0.24415097254954132], Predicted Digit = 4, True Digit = 5
# Test Sample 156: Confidence Scores = [-1.0155899843964802, -1.587002725070312, -0.7232816624790437, -0.6505820276905266, -0.06254550178360979, -1.2772374434107183, 0.3843535582029651, -0.44824537966943134, -0.7023644701899525, -0.8842549315834405], Predicted Digit = 6, True Digit = 6
# Test Sample 157: Confidence Scores = [0.6476244655735642, -1.0135982986979222, -0.7118946650887996, -1.0012573255665314, -1.1543911080731608, -0.4044489513070373, -0.25207374594355636, -0.9390650174702458, -0.7687614417939727, -0.22065115566791835], Predicted Digit = 0, True Digit = 0
# Test Sample 158: Confidence Scores = [-0.40141219964411046, -1.1350362310494002, 0.04258132072792614, 0.29197554140344345, -1.4160155549465665, -0.8499961950150574, -0.8545793279260129, -1.0238930264016282, -0.4556642882962646, 0.18454870813842214], Predicted Digit = 3, True Digit = 3
# Test Sample 159: Confidence Scores = [-0.807485863470257, -0.913115447026192, -0.48047071058114293, -1.0849129819380103, 0.3563915962106155, -0.5135096392083518, -0.3554646191536585, -0.5706346535175528, -0.9154479176119783, -0.28889947747572997], Predicted Digit = 4, True Digit = 4
# Test Sample 160: Confidence Scores = [-0.865277669034248, -1.0948464470431047, -0.3397073098418375, -2.600431228565998, 0.9395555230442504, -1.4442957410330097, -0.8242159264999324, -1.0098468904211069, -0.5522713365344458, -1.2377663467903384], Predicted Digit = 4, True Digit = 4
# Test Sample 161: Confidence Scores = [-0.7076481733612264, -1.0745461537223362, -0.7679617212887367, -1.152063962013235, -0.5427482848353652, -1.0197933920653846, 1.297684841798121, -0.9525972990294289, -1.0190527435904242, -0.8076726021019109], Predicted Digit = 6, True Digit = 6
# Test Sample 162: Confidence Scores = [-1.5138293132553766, -0.9206934257438305, -1.4857168224494293, -0.8297304894599166, -0.6642294108445626, 0.43804258440463145, -1.1466818244887518, -0.9555835129072149, -0.8122309000691517, -0.7262810420090304], Predicted Digit = 5, True Digit = 5
# Test Sample 163: Confidence Scores = [-1.15328942390528, -1.0212694490924346, -1.531235333250315, -1.3484233314923604, 0.6387302383686164, -1.047430683550417, -2.442394149045484, -0.6445234200849862, -1.1864642480729135, -0.3312693307838655], Predicted Digit = 4, True Digit = 4
# Test Sample 164: Confidence Scores = [-0.9225182465922426, -1.5297301462891715, -1.1708463872482047, -0.8990622503401379, 0.14786274058131332, -1.0206537588489584, 0.10329238558959224, -0.6125146221722723, -0.753807856728822, -1.156410899122936], Predicted Digit = 4, True Digit = 6
# Test Sample 165: Confidence Scores = [-1.1845672001690764, -1.2297418722173343, -0.9863989765817888, -0.6964590147054156, -1.5682013101497603, 0.8032312004537466, -0.981473323945662, -0.6676113927439279, -0.6507994043721671, -0.5534133811004727], Predicted Digit = 5, True Digit = 5
# Test Sample 166: Confidence Scores = [-0.999982779873616, -1.051163415255718, -0.8043238745892419, -1.8407181313786065, 0.516225747448642, -0.7221250637689419, -1.0637380043772258, -0.7335691633021749, -0.6519025300645225, -0.13127928769158922], Predicted Digit = 4, True Digit = 4
# Test Sample 167: Confidence Scores = [-1.0345507098310838, -1.0604807314007407, -0.6804364527789574, -1.008070222365326, -0.2616597083982943, 0.32831648137341857, -0.5318058698929085, -0.665494417790747, -1.3685419314064862, -0.895115803211844], Predicted Digit = 5, True Digit = 5
# Test Sample 168: Confidence Scores = [-0.689495056948581, 0.40275065077020666, -0.631289257912759, -1.556626620968759, -0.4428181200049005, -0.7148300581198499, -0.4779173374585202, -0.8259362328372324, -0.768591077114579, -0.6975450099950642], Predicted Digit = 1, True Digit = 1
# ...
# Test Sample 945: Confidence Scores = [-1.5316498472698175, -1.2264425367862468, 0.5329456125134744, -1.250731442938647, -1.2472586547095563, -1.7444205381981601, -0.6267920858723774, -1.1236593548522413, -1.062518731078702, -1.4981795706872778], Predicted Digit = 2, True Digit = 2
# Test Sample 946: Confidence Scores = [-1.0095025863714797, -0.6382582171121162, -0.7002957278282038, -0.16552315427232514, -0.5967734533904303, -1.2422441735567058, -1.3537992405853838, 0.4545200162698082, -0.16708664782176796, -0.0751332143060794], Predicted Digit = 7, True Digit = 7
# Test Sample 947: Confidence Scores = [-0.6234271241223673, -1.012558014626668, -0.9891239392076789, -1.362309203141829, -0.2688732255074391, -1.7449957933015918, -1.5037883725377255, -1.0194765872898017, 0.046278433084646825, -0.04317282021318068], Predicted Digit = 8, True Digit = 8
# Test Sample 948: Confidence Scores = [-0.7632777191943972, 0.26450927448977013, -0.3211799723628746, -0.8727536282787028, -0.3447365002930743, -0.3808892891635734, -0.36016052389547987, -0.6507074315111514, -0.5293854245776602, -0.29360498835504373], Predicted Digit = 1, True Digit = 1
# Test Sample 949: Confidence Scores = [-0.3832794198213392, 0.3041174132229547, -0.4153911272526498, -1.3096668814393944, -0.20287795685373267, -0.6270599662577747, -0.11100535561923876, -0.7798307500351741, -0.6290198386792228, -0.6324888828378387], Predicted Digit = 1, True Digit = 1
# Test Sample 950: Confidence Scores = [-1.0371171145524085, -0.9772941385844683, -0.2667433051639887, -1.5794843593335648, -1.348967466616375, -1.3823171827778238, -1.164145562525641, -0.25596084317041873, -1.0771494691604446, -0.9076666837041496], Predicted Digit = 7, True Digit = 7
# Test Sample 951: Confidence Scores = [-1.023420505635432, -1.0721514951859805, -1.0531617636330755, -1.5078397834749406, 0.3313067345755044, -0.8924853282552614, -0.8281694165962148, -0.1975450584853462, -0.4489450308305641, 0.016958919994166502], Predicted Digit = 4, True Digit = 5
# Test Sample 952: Confidence Scores = [-1.0616947464980326, -1.2010458711335432, -0.3176937081084185, -0.38267372078996764, 0.0708565706189784, -0.844063430483323, 0.2033756936109666, -0.42448623796322094, -0.3271549030230387, -0.49202511221205975], Predicted Digit = 6, True Digit = 6
# Test Sample 953: Confidence Scores = [-0.7917958413279166, -1.066689589805592, -1.158539351694884, -1.8583544844627513, 1.2174105587155475, -1.7345489387287703, -1.4623067069169629, -0.9282647995202177, -1.8966177659733794, -0.6112495190470378], Predicted Digit = 4, True Digit = 4
# Test Sample 954: Confidence Scores = [-1.1288290511473376, -0.07207985888859153, -1.0893002218847114, -1.3507510483322531, -0.08481535405645775, -1.3940199329098326, -1.5173866023999036, -1.3702869466816305, -0.8189214239670423, 0.4064922446691731], Predicted Digit = 9, True Digit = 9
# Test Sample 955: Confidence Scores = [-0.862834125465834, -1.0414016598332818, -1.5688523670348113, -0.3644504408463392, -0.9974388415989199, 0.4382136816556092, -0.24492814409066604, -0.8332520610888879, -0.7699021047743924, -0.43577722710887973], Predicted Digit = 5, True Digit = 5
# Test Sample 956: Confidence Scores = [-1.0179623529881117, 3.5938688807619648, 0.014622725335802464, -0.8957096244532173, -0.8018717219404045, -1.0069351889344382, -0.22121602240074362, -1.2785265831818626, -1.313814339796469, -0.5254085787231089], Predicted Digit = 1, True Digit = 1
# Test Sample 957: Confidence Scores = [-0.6288765910380301, -0.898562564995335, -0.1769706427445988, -0.05212497977250877, -0.09119153990087586, -0.23076294500352768, -1.1461696314588676, -1.0383920656905168, -0.46368573888335013, -0.7321984020673681], Predicted Digit = 3, True Digit = 3
# Test Sample 958: Confidence Scores = [0.5295720119464139, -1.1718736744318303, -0.5251394130314976, 0.05944511285464623, -1.730782565670358, -1.3516460898127105, -0.21680168655245463, -0.8757732730145094, -0.8777916153476195, -0.0897741215616453], Predicted Digit = 0, True Digit = 3
# Test Sample 959: Confidence Scores = [-1.0693018080477845, -0.2300450957268895, -0.5581009044468332, -0.5820052058783631, 0.09384280391324393, -0.4504821019094719, -0.5791083249578927, -0.8524942435817953, -0.03709900705787864, -0.0837332281134293], Predicted Digit = 4, True Digit = 4
# Test Sample 960: Confidence Scores = [-1.1488230170848477, -0.5958367272899906, -0.8947891913766918, -0.5543700276226038, -0.06166915250198109, -0.5762788009038422, -0.7275428059264553, -0.26755158401666124, -0.7825604739645321, -0.09823075580438577], Predicted Digit = 4, True Digit = 7
# Test Sample 961: Confidence Scores = [-1.0116121527261326, -0.8185066739432013, -1.8639161320826059, -1.5569238526254816, -0.8956178635602391, -0.7522848183725946, -0.6692546465338222, -1.1576745819199923, 0.6154969272131192, -1.054557728629224], Predicted Digit = 8, True Digit = 8
# Test Sample 962: Confidence Scores = [-1.038113179554389, -0.8778950453724526, -0.6555755720586791, -0.7353024990182647, -0.45836846770215645, -1.4076115988096036, -1.119545872222274, -0.3669159916603844, -0.2279179495557849, 0.12185458744011324], Predicted Digit = 9, True Digit = 9
# Test Sample 963: Confidence Scores = [-1.1584648536942865, 0.2667158796173186, -0.6789246538577699, -0.8878611790188232, -0.3733729215433997, -0.38396851866004245, -0.3929372638243041, -0.43386518485418074, -0.7564451428873616, -0.17622395972825278], Predicted Digit = 1, True Digit = 1
# Test Sample 964: Confidence Scores = [-0.9401296091830234, 0.24895857119118078, -0.4518626955665922, -0.7649622261508888, -0.45491588492636476, -0.3399609608194697, -0.06155056777582883, -0.3793030675408293, -0.7335669006860969, -0.40176106342487083], Predicted Digit = 1, True Digit = 1
# Test Sample 965: Confidence Scores = [0.10201025532148095, -1.1690693210725605, -1.129765276115846, -0.42621406789562466, -1.6535083050986747, -0.794787606178328, -0.13720568338085182, -0.625462111725843, -0.9365751527707086, -0.7044848547920697], Predicted Digit = 0, True Digit = 6
# Test Sample 966: Confidence Scores = [-0.9129177270976814, -1.073773195693, -1.2182863045139742, -2.0302458652323065, -0.3929573885202271, -0.7050807578963533, -1.423810353218715, -0.5346106255765544, -0.8643737975871275, 0.20362116000753203], Predicted Digit = 9, True Digit = 9
# Test Sample 967: Confidence Scores = [-1.313099281372447, 0.3943415787173912, -0.7559992678982975, -1.498832109542868, -0.6201746672520896, -0.8197418108575805, -0.3458425422699447, -0.5948980833888149, -0.911752094440155, -0.5149955079259053], Predicted Digit = 1, True Digit = 1
# Test Sample 968: Confidence Scores = [-0.8753468255800508, -0.7512863860373437, -0.937979284033932, -1.6836858854982815, 0.7260642041968239, -1.353771467016497, -1.5846831619437582, -1.2521525762597405, -0.37387514455176046, -0.4619803762315093], Predicted Digit = 4, True Digit = 4
# Test Sample 969: Confidence Scores = [-1.1149593256632002, -1.2775932158557228, -0.5461776272475579, -0.1179081383734532, 0.2968039694164724, -0.21586178904700407, -0.13924117792615726, -0.30628568757953056, -0.44688361617911176, -0.3811602936907208], Predicted Digit = 4, True Digit = 4
# Test Sample 970: Confidence Scores = [-1.0689389524602293, -0.8833753529910195, -0.9228717097768074, -0.7367460849612233, -0.5206499658845395, 0.23704424194813553, -0.7426887069292897, -1.060434506777361, -1.133684278019574, -0.5306018361615384], Predicted Digit = 5, True Digit = 5
# Test Sample 971: Confidence Scores = [-1.002325395626831, -0.9850005580198832, -1.3192692239496386, -1.0862906437017463, 0.6400733928596308, -1.4736670977507285, -2.093568983388214, -0.8894850118128318, -0.6105936968311174, -0.24959510743745345], Predicted Digit = 4, True Digit = 4
# Test Sample 972: Confidence Scores = [1.3126182515357745, -0.47379247792942963, -0.8318699674617271, -1.1647013445000207, -0.5295376343640725, -1.4672690539477025, -1.6855557637602878, -0.7134950144487279, -1.1842693346715354, -1.2678756345229591], Predicted Digit = 0, True Digit = 0
# Test Sample 973: Confidence Scores = [-0.868553060925652, -1.450839230949785, -0.929782000139258, -1.4451976069120827, 0.22006995388406456, -0.665128344723474, 0.7851838565493634, -1.0626600707672664, -0.9474304774777096, -1.3276301024862314], Predicted Digit = 6, True Digit = 6
# Test Sample 974: Confidence Scores = [-0.9058842998986785, -1.2068073341019587, 1.3681047896257774, -0.8275516842476921, -1.480735920242144, -0.9042805984936922, -1.2800037310598475, -1.1757510133349427, -1.0537087001824577, -0.16430407107009082], Predicted Digit = 2, True Digit = 2
# Test Sample 975: Confidence Scores = [-0.33971737312020167, -1.236036440735234, -0.15461347307369772, -0.4458954081601169, -0.5072289733345693, -0.7287153874982573, -0.7811979656428542, -0.46830651020683717, -0.15302415837986208, -0.8031401275554217], Predicted Digit = 8, True Digit = 2
# Test Sample 976: Confidence Scores = [-0.4433503154745362, -0.9525822575185791, -0.6360824035546847, -0.21411254593512533, -0.7570712676601529, -0.8362767978134753, -0.7960865785445078, -0.8720698456718758, -0.0960611523065275, -0.459831047888432], Predicted Digit = 8, True Digit = 3
# Test Sample 977: Confidence Scores = [-1.1220582698274217, 0.3727450905137679, -1.0010464381416133, -2.0560656879655843, -0.16546831942610052, -1.3403488346256647, -0.5702423418120204, -0.7372183874094185, -1.812192479305929, -1.1622790678097514], Predicted Digit = 1, True Digit = 1
# Test Sample 978: Confidence Scores = [-0.9473528675599169, -0.6731040991342749, -1.2149026740004811, -0.5771012898317179, -0.05472387786111124, 0.13428864040702249, -1.0861105173059629, -1.200042294393814, -0.6773170286875717, -0.6807181147177317], Predicted Digit = 5, True Digit = 5
# Test Sample 979: Confidence Scores = [-0.5354285658240536, 0.3058919885260493, -0.45456786719707915, -1.638154574641133, -0.18887162861243484, -0.7503902178214669, -0.47567880012448266, -0.8053685181811483, -0.723176472904718, -0.86362631019279], Predicted Digit = 1, True Digit = 1
# Test Sample 980: Confidence Scores = [-0.8285702462089228, -1.0778062845578908, 0.3347080229262467, -0.556952813578085, -0.22002048051883105, -0.5480058619681185, -0.533423514155021, -0.6968769607648423, -0.44677357664776407, -0.5787561135882101], Predicted Digit = 2, True Digit = 2
# Test Sample 981: Confidence Scores = [0.2543839296671718, -1.0773126902800025, -1.5681109230689685, -0.3563031521867711, -1.157940086995777, -1.119545443409907, -0.6475581923179379, -0.8524979799476727, -1.0279636401203134, -0.6291719555311713], Predicted Digit = 0, True Digit = 0
# Test Sample 982: Confidence Scores = [-0.45015418481220115, -0.7636588597996042, 0.05046860853420751, -0.26279555936247956, -1.198076863186381, -1.2270486186274283, -0.9875557014724696, -0.7824799709866184, 0.09816067668743768, -0.9069625620269429], Predicted Digit = 8, True Digit = 3
# Test Sample 983: Confidence Scores = [-0.9540127718759133, -0.8131719208910942, -1.1938310433005392, -2.440773099190152, 0.1563497336806846, -0.447249157875429, -0.8135224639318083, -1.2070259244651804, 0.05710823376501859, -1.902081795219192], Predicted Digit = 4, True Digit = 8
# Test Sample 984: Confidence Scores = [-1.0128647411249507, 0.26239808280102583, -0.47124805726155955, -1.0572603641534384, -0.2625370475357076, -0.3056198452315981, -0.2894918973853544, -0.603815459094709, -0.6739748632883488, -0.3404697386440372], Predicted Digit = 1, True Digit = 1
# Test Sample 985: Confidence Scores = [-0.9316650677872873, -1.0666855659714822, 1.0413492782897995, -1.9703323105696788, -0.9849943092125424, -1.7474902839863804, -1.6891677452962408, -1.1320193432693313, -0.5937270887975274, -1.4057950618580908], Predicted Digit = 2, True Digit = 2
# Test Sample 986: Confidence Scores = [-1.2952542045316735, -1.2405423304028704, -1.9616843877783658, -1.3781219942096632, -1.0300541667954686, -0.49830338148048003, 1.5689136152991923, -1.0452979094597779, -0.7859385033277576, -0.5011745446879317], Predicted Digit = 6, True Digit = 6
# Test Sample 987: Confidence Scores = [-0.8589971078345153, -0.8860625165332201, -0.7274286255749576, -1.4918801777032107, -0.6483818349683002, -0.7092423424953171, -0.5467621193023086, 0.15256346431713752, -0.5503096190332577, 0.018444355362038544], Predicted Digit = 7, True Digit = 7
# Test Sample 988: Confidence Scores = [-0.8657344404545444, 0.24057969592763112, -0.3645507631833695, -0.8899470848933798, -0.2350266852947724, -0.13689358407414468, -0.06264807771397457, -0.660734894500145, -0.3324586152766625, -0.234894174525603], Predicted Digit = 1, True Digit = 1
# Test Sample 989: Confidence Scores = [-0.20986972100561024, -1.3341921020965357, -0.64755414372112, -0.5099996392503283, -0.8610638342678509, -0.8924057121037012, 0.0979527362871858, -0.7197107975668764, -0.6335214114397612, -0.7847932856517401], Predicted Digit = 6, True Digit = 6
# Test Sample 990: Confidence Scores = [-1.4676508947416327, 0.13969871678682869, -0.2987258910597361, -0.854826976988205, -0.45102991627426975, -1.0865976165109177, -1.2705338492450802, -0.28311042502082545, -1.5969458595826331, -1.1509373464670716], Predicted Digit = 1, True Digit = 2
# Test Sample 991: Confidence Scores = [1.036878031911517, -0.7869882445453007, -1.3491057090509881, 0.3138933760640546, -1.0377599147924075, -1.2573208466218517, -1.0820564193506625, -0.9126535670953232, 0.1775416661760205, -1.1226757705114023], Predicted Digit = 0, True Digit = 3
# Test Sample 992: Confidence Scores = [-0.7334345077184988, -1.0057215566259048, -0.8739820533152909, -0.6635085453749803, 0.4002103445731191, -1.8893448880064698, -1.1815895284699647, -0.45945598944805416, -0.039447315310330265, -0.12889570470977227], Predicted Digit = 4, True Digit = 9
# Test Sample 993: Confidence Scores = [0.7235497262861863, -0.6809618650715401, -0.7486580425492293, -1.7251550879518873, -1.2144692649573479, -1.0696224371093588, -0.9408375781061948, -1.4141515467852643, -0.9469082872575244, -0.07481473269392408], Predicted Digit = 0, True Digit = 0
# Test Sample 994: Confidence Scores = [0.048215447182570675, 0.36244223142657844, -0.2690851646046737, -1.6200565301637515, -0.046973193057876665, -1.0537846173353063, -0.508472008193249, -0.8832660727305832, -0.44368291677086213, -0.8923231227863634], Predicted Digit = 1, True Digit = 1
# Test Sample 995: Confidence Scores = [-0.7616512964973782, -1.0535953615429934, -0.06491106473557325, -1.0018211398294807, -0.2692648403922232, -0.5723273562502933, -0.8875701161790569, -1.1190432173348068, -0.9510503234087152, -1.0477066042092338], Predicted Digit = 2, True Digit = 2
# Test Sample 996: Confidence Scores = [-1.5183629162596703, -1.258942336442557, 0.28959565914174457, -2.2104378484668326, 0.16337331258087456, -0.43738813455337805, -1.2797671384295584, -0.9938453389108136, -1.4986044983994196, -2.2998136617114713], Predicted Digit = 2, True Digit = 2
# Test Sample 997: Confidence Scores = [1.7070505697673484, -1.7166730108447796, -0.8881720595353083, -0.27637267587226655, -1.2466377976987668, -2.2821260608554543, -1.7184080538308482, -0.9907234691501796, -0.7937084291907633, -1.090160494144834], Predicted Digit = 0, True Digit = 0
# Test Sample 998: Confidence Scores = [-0.8976830350199404, -0.9404855833348008, -0.6273580452797956, -0.17207065710648045, -1.1004857859801362, -1.0063866428465347, -1.2493788812427995, 0.023508319846878126, -0.7491606259285465, 0.15269543594659818], Predicted Digit = 9, True Digit = 8
# Test Sample 999: Confidence Scores = [-1.0471245834187577, -1.1218060020825344, -0.7992895439175094, -0.4024656703742284, 0.08955337339995588, -1.0130437269445751, -0.90044656775992, -0.1565117069989995, -0.49404886995536407, 0.04654522297029242], Predicted Digit = 4, True Digit = 9
# Overall Testing Accuracy: 82.80%
# Total Testing Time: 7.76 seconds

# %% [markdown]
# 🌿Test with actual Image

# %% [markdown]
# range of predictions

# %%
import matplotlib.pyplot as plt
import numpy as np

# Specify the range of indices to visualize
start_index = 70
end_index = 90

# Number of rows and columns for the grid
rows = int(np.ceil((end_index - start_index) / 5))  # 5 images per row
cols = 5

# Create a figure
fig, axes = plt.subplots(rows, cols, figsize=(15, 3 * rows))

# Flatten axes array for easier iteration
axes = axes.flatten()

# Iterate through the specified range
for idx, ax in zip(range(start_index, end_index), axes):
    # Predicted and true labels for the current index
    predicted_digit = predictions[idx]
    true_digit = y_test_subset[idx]

    # Reshape the flattened image back to its original shape (28x28)
    image = x_test_subset[idx].reshape(28, 28)

    # Determine correctness
    if predicted_digit == true_digit:
        status = "correct✔️"
    else:
        status = "wrong✖️"
    
    # Plot the image
    ax.imshow(image, cmap='gray')  # Use 'gray' colormap for MNIST
    ax.set_title(f"Pred: {predicted_digit}, True: {true_digit}\n{status}")
    ax.axis("off")  # Hide axes for cleaner visuals

# Turn off unused subplots
for ax in axes[len(range(start_index, end_index)):]:
    ax.axis("off")

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Specify the range of indices to visualize
start_index = 120
end_index = 140

# Number of rows and columns for the grid
rows = int(np.ceil((end_index - start_index) / 5))  # 5 images per row
cols = 5

# Create a figure
fig, axes = plt.subplots(rows, cols, figsize=(15, 3 * rows))

# Flatten axes array for easier iteration
axes = axes.flatten()

# Iterate through the specified range
for idx, ax in zip(range(start_index, end_index), axes):
    # Predicted and true labels for the current index
    predicted_digit = predictions[idx]
    true_digit = y_test_subset[idx]

    # Reshape the flattened image back to its original shape (28x28)
    image = x_test_subset[idx].reshape(28, 28)

    # Determine correctness
    if predicted_digit == true_digit:
        status = "correct✔️"
    else:
        status = "wrong✖️"
    
    # Plot the image
    ax.imshow(image, cmap='gray')  # Use 'gray' colormap for MNIST
    ax.set_title(f"Pred: {predicted_digit}, True: {true_digit}\n{status}")
    ax.axis("off")  # Hide axes for cleaner visuals

# Turn off unused subplots
for ax in axes[len(range(start_index, end_index)):]:
    ax.axis("off")

# Adjust layout and show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# one prediction

# %%
import matplotlib.pyplot as plt
import numpy as np

index_to_visualize = 198

# predicted digit for this index
predicted_digit = predictions[index_to_visualize]

# true digit for this index
true_digit = y_test_subset[index_to_visualize]

# Reshape the flattened image back to its original shape (28x28)
image = x_test_subset[index_to_visualize].reshape(28, 28)

# Plot the image
plt.imshow(image, cmap='gray')
plt.title(f"Predicted: {predicted_digit}, True: {true_digit}")
plt.show()
